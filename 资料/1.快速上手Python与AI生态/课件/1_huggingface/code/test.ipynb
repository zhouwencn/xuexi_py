# %%
name = "JupyterLab"
print(name)
# Out:
# JupyterLab

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3], [10, 30, 20])
plt.show()

# %%
from IPython.display import HTML

HTML("<h2 style='color: blue'>运行结果</h2>")
# Out:
# <h2 style='color: blue'>运行结果</h2>
